# %%
import pandas as pd

# %% [markdown]
# # Pandas Series

# %%
series = pd.Series([3.3, 3.9, 3.5, 2.8, 2.5, 3.0])
series.name = "Student CGPA's"
series
# Out:
# 0    3.3
# 1    3.9
# 2    3.5
# 3    2.8
# 4    2.5
# 5    3.0
# Name: Student CGPA's, dtype: float64

# %%
series.values
# Out:
# array([3.3, 3.9, 3.5, 2.8, 2.5, 3. ])

# %%
series.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
type(series.values)
# Out:
# numpy.ndarray

# %%
series[1]
# Out:
# 3.9

# %%
series.index = [      # unlike lists we can explicitly define index names
    "Tom",
    "Bruce",
    "Tony",
    "Steve",
    "Harry",
    "John"
]
series
# Out:
# Tom      3.3
# Bruce    3.9
# Tony     3.5
# Steve    2.8
# Harry    2.5
# John     3.0
# Name: Student CGPA's, dtype: float64

# %%
series["Tom"]        # by defining indexes you can access the values like python dictionaries
# Out:
# 3.3

# %%
series.Harry         # can also access values using .index
# Out:
# 2.5

# %%
series.iloc[0]       # you can also use iloc to get values using numeric indexes
# Out:
# 3.3

# %%
series.iloc[[0, 1]]   # you can also get multiple indexes
# Out:
# Tom      3.3
# Bruce    3.9
# Name: Student CGPA's, dtype: float64

# %%
series >= 3.0         # conditional selection
# Out:
# Tom       True
# Bruce     True
# Tony      True
# Steve    False
# Harry    False
# John      True
# Name: Student CGPA's, dtype: bool

# %% [markdown]
# # Operations

# %%
series + 0.1
# Out:
# Tom      3.4
# Bruce    4.0
# Tony     3.6
# Steve    2.9
# Harry    2.6
# John     3.1
# Name: Student CGPA's, dtype: float64

# %%
(series * 100) / 4
# Out:
# Tom      82.5
# Bruce    97.5
# Tony     87.5
# Steve    70.0
# Harry    62.5
# John     75.0
# Name: Student CGPA's, dtype: float64

# %%
series          # Above operations don't change the original values
# Out:
# Tom      3.3
# Bruce    3.9
# Tony     3.5
# Steve    2.8
# Harry    2.5
# John     3.0
# Name: Student CGPA's, dtype: float64

# %% [markdown]
# # Methods

# %%
series.mean()
# Out:
# 3.1666666666666665

# %%
series.std()
# Out:
# 0.5046450898073483

# %%
series.count()
# Out:
# 6

# %% [markdown]
# # Pandas DataFrames

# %%
df = pd.DataFrame({
    "Name" : [    "Tom", "Bruce", "Tony", "Steve", "Harry", "John"],
    "CGPA": [3.3, 3.9, 3.5, 2.8, 2.5, 3.0],
    "Percentage": [82.5, 97.5, 87.5, 70.0, 62.5, 75.0],
    "Attendance": ["95%", "100%", "90%", "87%", "80%", "93%"]
})
df
# Out:
#     Name  CGPA  Percentage Attendance
# 0    Tom   3.3        82.5        95%
# 1  Bruce   3.9        97.5       100%
# 2   Tony   3.5        87.5        90%
# 3  Steve   2.8        70.0        87%
# 4  Harry   2.5        62.5        80%
# 5   John   3.0        75.0        93%

# %%
df.head()       # Top 5 rows
# Out:
#     Name  CGPA  Percentage Attendance
# 0    Tom   3.3        82.5        95%
# 1  Bruce   3.9        97.5       100%
# 2   Tony   3.5        87.5        90%
# 3  Steve   2.8        70.0        87%
# 4  Harry   2.5        62.5        80%

# %%
df.tail()       # Bottom 5 rows
# Out:
#     Name  CGPA  Percentage Attendance
# 1  Bruce   3.9        97.5       100%
# 2   Tony   3.5        87.5        90%
# 3  Steve   2.8        70.0        87%
# 4  Harry   2.5        62.5        80%
# 5   John   3.0        75.0        93%

# %%
df.columns
# Out:
# Index(['Name', 'CGPA', 'Percentage', 'Attendance'], dtype='object')

# %%
df.index      # you can also change the indexes like in Series
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        6 non-null      object
#  1   CGPA        6 non-null      float64
#  2   Percentage  6 non-null      float64
#  3   Attendance  6 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 320.0+ bytes

# %%
df.size
# Out:
# 24

# %%
df.shape
# Out:
# (6, 4)

# %%
df.describe()
# Out:
#            CGPA  Percentage
# count  6.000000    6.000000
# mean   3.166667   79.166667
# std    0.504645   12.616127
# min    2.500000   62.500000
# 25%    2.850000   71.250000
# 50%    3.150000   78.750000
# 75%    3.450000   86.250000
# max    3.900000   97.500000

# %%
df.dtypes
# Out:
# Name           object
# CGPA          float64
# Percentage    float64
# Attendance     object
# dtype: object

# %%
df.iloc[1]
# Out:
# Name          Bruce
# CGPA            3.9
# Percentage     97.5
# Attendance     100%
# Name: 1, dtype: object

# %%
df[1:3]
# Out:
#     Name  CGPA  Percentage Attendance
# 1  Bruce   3.9        97.5       100%
# 2   Tony   3.5        87.5        90%

# %%
df.iloc[1:3]
# Out:
#     Name  CGPA  Percentage Attendance
# 1  Bruce   3.9        97.5       100%
# 2   Tony   3.5        87.5        90%

# %%
df.loc[df["CGPA"] > 3.0]
# Out:
#     Name  CGPA  Percentage Attendance
# 0    Tom   3.3        82.5        95%
# 1  Bruce   3.9        97.5       100%
# 2   Tony   3.5        87.5        90%

# %%
df.drop(0)
# Out:
#     Name  CGPA  Percentage Attendance
# 1  Bruce   3.9        97.5       100%
# 2   Tony   3.5        87.5        90%
# 3  Steve   2.8        70.0        87%
# 4  Harry   2.5        62.5        80%
# 5   John   3.0        75.0        93%

# %%
df.drop(columns=["CGPA", "Attendance"])
# Out:
#     Name  Percentage
# 0    Tom        82.5
# 1  Bruce        97.5
# 2   Tony        87.5
# 3  Steve        70.0
# 4  Harry        62.5
# 5   John        75.0

# %%
country = pd.Series(["England", "England", "England", "Canada"])
df["Country"] = country
df
# Out:
#     Name  CGPA  Percentage Attendance  Country
# 0    Tom   3.3        82.5        95%  England
# 1  Bruce   3.9        97.5       100%  England
# 2   Tony   3.5        87.5        90%  England
# 3  Steve   2.8        70.0        87%   Canada
# 4  Harry   2.5        62.5        80%      NaN
# 5   John   3.0        75.0        93%      NaN

# %%
CGPA = df["CGPA"]

# %%
CGPA.min(), CGPA.max()
# Out:
# (2.5, 3.9)

# %%
CGPA.sum()
# Out:
# 19.0

# %%
CGPA.mean()
# Out:
# 3.1666666666666665

# %%
CGPA.std()
# Out:
# 0.5046450898073483

# %%
CGPA.median()
# Out:
# 3.15

# %%
CGPA.describe()
# Out:
# count    6.000000
# mean     3.166667
# std      0.504645
# min      2.500000
# 25%      2.850000
# 50%      3.150000
# 75%      3.450000
# max      3.900000
# Name: CGPA, dtype: float64
